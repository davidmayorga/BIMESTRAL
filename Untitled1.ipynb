# %% [markdown]
# <a href="https://colab.research.google.com/github/davidmayorga/BIMESTRAL/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("------------------------------------")
print("----------Elije tu grafica----------")
print("------------------------------------")
import numpy as np
import matplotlib.pyplot as plt 
from math import log  
import math as m
from numpy import linspace, pi, sin, cos
from matplotlib.pyplot import pyplot, show, xlim,ylim, xticks, legend

# input
bandera = False 


print("¿Cual funcion deseas realizar?: \n")
print("1. Lineal ")
print("2. cuadratica")
print("3. cubica")
print("4. Logaritmica")
print("5. Exponencial ")
print("6. Trigonometrica")

opcion = int(input(" Dame la opcion que deseas: "))

if (opcion == 1):
  N = 100
  def f(m,x,b):
    return m*x + b

  m = int(input("Digite el valor de la pendiente: "))
  b = int(input("Digite el valor de el punto de corte con el eje y: "))
  x = np.linspace(-10, 10, num = N)
  y = f(m,x,b)
  plt.plot(x,y, color = "r")
  plt.xlabel("x")
  plt.ylabel("y")
  plt.title("Funcion lineal: y =mx + b")
  plt.grid()
  plt.axhline(y=0, color ="b")
  plt.axvline(x =0, color = "b")
  plt.show()
  plt.savefig("funcion_lineal.png")


elif (opcion == 2):
  a =float(input("ingrese el valor de (a):\n"))
  b=float(input("ingrese el valor de (b):\n"))
  c=float(input("ingrese el valor de (c):\n"))
  disc=(b**2)-(4*a*c)
  raiz=(disc)**(0.5)

  if(disc>0):
    x1=((-b)+raiz)/(2*a)
    x2=((-b)-raiz)/(2*a)
    print("x1= ",x1)
    print("x2= ",x2)

  elif(disc==0):
    x1=((-b)+raiz)/(2*a)
    x2=((-b)-raiz)/(2*a)
    print("x1= ",x1)
    print("x2= ",x2)
  else:
    print("Solucion imaginaria")

  def f(x):
    return a*(x**2)+b*x+c

  x = np.linspace(-100,50+np.pi,100)

  pyplot.plot(x,[f(i)for i in x])

  pyplot.axhline(0, color= "black")
  pyplot.axvline(0, color= "black")

  pyplot.xlim(-50,50)
  pyplot.ylim(-50,50)

  pyplot.savefig("output.png")
  pyplot.show()


elif(opcion == 3):
  a = int(input("Ingrgese el valor de a:"))
  b = int(input("Ingrgese el valor de b:"))
  c = int(input("Ingrgese el valor de c:"))
  d = int(input("Ingrgese el valor de d:"))

  
  xticks([-pi,-pi/2,0,pi/2,pi],[r'$-\pi$',r'$-\pi/2$', r'$0$', r'$\pi/2$', r'$\pi$'])
  show()
